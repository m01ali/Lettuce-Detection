# %% [markdown]
# Data: https://universe.roboflow.com/the-university-of-adelaide-wweml/lettuceyolov8/browse?queryText=&pageSize=50&startingIndex=200&browseQuery=true

# %% [markdown]
# ### Setup

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
# !unzip -q ../train-data.zip -d ../

# %% [markdown]
# ### Train

# %%
# Train YOLOv5s Classification on lettuce for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 3 --data custom_data.yaml --weights yolov5x.pt --nosave --cache
# Out:
# 2024-01-01 11:42:13.837447: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-01 11:42:13.837511: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-01 11:42:13.837555: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# The mAP at IoU=0.50 is 0.837 and mAP at IoU=0.50:0.95 is 0.468 for the last epoch.

# %% [markdown]
# ### Test

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# video 1/1 (1/310) /content/video.mp4: 640x512 16 lettuces, 78.7ms
# video 1/1 (2/310) /content/video.mp4: 640x512 16 lettuces, 50.5ms
# video 1/1 (3/310) /content/video.mp4: 640x512 16 lettuces, 50.5ms
# video 1/1 (4/310) /content/video.mp4: 640x512 16 lettuces, 50.5ms
# ...
